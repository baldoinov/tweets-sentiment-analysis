# %%
import os
from google.colab import drive

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Projetos/tweets-sentiment-analysis')
# Out:
# Mounted at /content/drive

# %%
# %%shell
# pwd
# Out:
# /content/drive/MyDrive/Projetos/tweets-sentiment-analysis

# %%
# %%shell
#
# pip install --no-deps -qq -r requirements.txt
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for src (pyproject.toml) ... done

# %%
# %%shell
# pip install -U 'jsonargparse[signatures]>=4.27.7'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.7/206.7 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 kB 28.9 MB/s eta 0:00:00
# ...

# %%
# %%shell
# python src/main.py fit --config models/bertimbau-ft-full/config.yaml
# Out:
# Seed set to 42
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at neuralmind/bert-base-portuguese-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Map: 100% 900688/900688 [00:58<00:00, 15276.55 examples/s]
# Map: 100% 900688/900688 [00:04<00:00, 184121.37 examples/s]
# Map: 100% 900688/900688 [00:30<00:00, 29634.44 examples/s]
# Map: 100% 900688/900688 [00:07<00:00, 126153.97 examples/s]
# Map: 100% 900688/900688 [00:08<00:00, 103143.01 examples/s]
# Map: 100% 900688/900688 [00:02<00:00, 440723.19 examples/s]
# Map: 100% 900688/900688 [11:44<00:00, 1278.67 examples/s]
# ...
